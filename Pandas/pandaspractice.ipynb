# %%
import pandas as pd

# %%
# create dataset and create Series ,create DataFrame , build csv file , read_csv(file) 
data = {
    'Name':['Mike_Hertz' , 'Andrew' , 'John' , 'Altman' , 'adrIENNE'],
    'Age':[30 , 40 , 44 , 29 , 43],
    'Gender':[1 , 1 , 1 , 1 , 0],
    'Discharge Date':['2024-02-02' , '2019-08-26' , '2022-10-07' , '2020-12-18' , '2022-10-09'],
    'Medication':['Paracetamol' , 'Ibuprofen' , 'Aspirin' , 'Ibuprofen' , 'Penicillin'],
    'Test Results':['Normal' , 'Inconclusive' , 'Normal' , 'Abnormal' , ' Abnormal']
}

s = pd.Series(data)
s
# Out:
# Name                   [Mike_Hertz, Andrew, John, Altman, adrIENNE]
# Age                                            [30, 40, 44, 29, 43]
# Gender                                              [1, 1, 1, 1, 0]
# Discharge Date    [2024-02-02, 2019-08-26, 2022-10-07, 2020-12-1...
# Medication        [Paracetamol, Ibuprofen, Aspirin, Ibuprofen, P...
# Test Results      [Normal, Inconclusive, Normal, Abnormal,  Abno...
# dtype: object

# %%
# create DataFrame
df = pd.DataFrame(s , columns=['PatientData'])
df
# Out:
#                                                       PatientData
# Name                 [Mike_Hertz, Andrew, John, Altman, adrIENNE]
# Age                                          [30, 40, 44, 29, 43]
# Gender                                            [1, 1, 1, 1, 0]
# Discharge Date  [2024-02-02, 2019-08-26, 2022-10-07, 2020-12-1...
# Medication      [Paracetamol, Ibuprofen, Aspirin, Ibuprofen, P...
# Test Results    [Normal, Inconclusive, Normal, Abnormal,  Abno...

# %%
df.to_csv('PatientHistory.csv')

# %%
df = pd.read_csv(r'C:\Users\Muhammad Yahya\Downloads\python\Pandas\PatientHistory.csv',index_col=0) #r means row data
df
# Out:
#                                                       PatientData
# Name            ['Mike_Hertz', 'Andrew', 'John', 'Altman', 'ad...
# Age                                          [30, 40, 44, 29, 43]
# Gender                                            [1, 1, 1, 1, 0]
# Discharge Date  ['2024-02-02', '2019-08-26', '2022-10-07', '20...
# Medication      ['Paracetamol', 'Ibuprofen', 'Aspirin', 'Ibupr...
# Test Results    ['Normal', 'Inconclusive', 'Normal', 'Abnormal...

# %%
# call particular column using 'Method:1'
c = df['PatientData']
c
# Out:
# Name              ['Mike_Hertz', 'Andrew', 'John', 'Altman', 'ad...
# Age                                            [30, 40, 44, 29, 43]
# Gender                                              [1, 1, 1, 1, 0]
# Discharge Date    ['2024-02-02', '2019-08-26', '2022-10-07', '20...
# Medication        ['Paracetamol', 'Ibuprofen', 'Aspirin', 'Ibupr...
# Test Results      ['Normal', 'Inconclusive', 'Normal', 'Abnormal...
# Name: PatientData, dtype: object

# %%
pat_age = df['PatientData'].Age

print(pat_age)
print(type(pat_age))
# Out:
# [30, 40, 44, 29, 43]
# <class 'str'>

# %%
pat_age = df['PatientData'].Age[1:]
print(pat_age)
# Out:
# 30, 40, 44, 29, 43]

# %%
pat_age = df['PatientData'].Age[-5:-1]
print(pat_age)
# Out:
# , 43

# %%
pat_age = df['PatientData'].Medication[0]
pat_age
# Out:
# '['

# %%
print(type(pat_age))
# Out:
# <class 'str'>
